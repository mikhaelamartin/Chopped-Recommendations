# %%
import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
chopped = pd.read_csv('data/chopped.csv')

# %%
chopped.head(3)
# Out:
#    season  season_episode  series_episode                      episode_name  \
# 0       1               1               1  "Octopus, Duck, Animal Crackers"
# 1       1               2               2      "Tofu, Blueberries, Oysters"
# 2       1               3               3    "Avocado, Tahini, Bran Flakes"
#
#                                        episode_notes          air_date  \
# 0  This is the first episode with only three offi...  January 13, 2009
# 1  This is the first of a few episodes with five ...  January 20, 2009
# 2                                                NaN  January 27, 2009
#
#           judge1              judge2         judge3  \
# 0    Marc Murphy  Alex Guarnaschelli  Aarón Sánchez
# 1  Aarón Sánchez  Alex Guarnaschelli    Marc Murphy
# 2  Aarón Sánchez  Alex Guarnaschelli    Marc Murphy
#
#                                            appetizer  \
# 0   baby octopus, bok choy, oyster sauce, smoked ...
# 1               firm tofu, tomato paste, prosciutto
# 2   lump crab meat, dried shiitake mushrooms, pin...
#
#                                               entree  \
# 0          duck breast, green onions, ginger, honey
# 1   daikon, pork loin, Napa cabbage, Thai chiles,...
# 2   ground beef, cannellini beans, tahini paste, ...
#
#                                              dessert          contestant1  \
# 0              prunes, animal crackers, cream cheese  Summer Kriegshauser
# 1   phyllo dough, gorgonzola cheese, pineapple ri...      Raymond Jackson
# 2              brioche, cantaloupe, pecans, avocados     Margaritte Malfy
#
#                                     contestant1_info         contestant2  \
# 0    Private Chef and Nutrition Coach  New York  NY        Perry Pollaci
# 1   Private Caterer and Culinary Instructor  West...   Klaus Kronsteiner
# 2   Executive Chef and Co-owner  La Palapa  New Y...    Rachelle Rodwell
#
#                                     contestant2_info           contestant3  \
# 0   Private Chef and Sous chef  Bar Blanc  New Yo...      Katie Rosenhouse
# 1   Chef de cuisine  Liberty National Golf Course...   Christopher Jackson
# 2   Chef de cuisine  SoHo Grand Hotel  New York  NY            Chris Burke
#
#                                     contestant3_info     contestant4  \
# 0       Pastry Chef  Olana Restaurant  New York  NY      Sandy Davis
# 1   Executive Chef and Owner  Ted and Honey  Broo...   Pippa Calland
# 2                        Private Chef  New York  NY    Andre Marrero
#
#                                     contestant4_info
# 0   Catering Chef  Showstoppers Catering at Union...
# 1   Owner and Chef  Chef for Hire LLC  Newville  PA
# 2   Chef tournant  L’Atelier de Joël Robuchon  Ne...

# %%
chopped
# Out:
#                        episode_name  \
# 0    Octopus, Duck, Animal Crackers
# 1        Tofu, Blueberries, Oysters
# 2      Avocado, Tahini, Bran Flakes
# 3     Banana, Collard Greens, Grits
# 4      Yucca, Watermelon, Tortillas
# ..                              ...
# 564                 Terrine Cuisine
# 565                Time and Turmoil
# 566                    Jarring Jars
# 567               Cauliflower Power
# 568              Quail Without Fail
#
#                                          episode_notes             judge1  \
# 0    This is the first episode with only three offi...        Marc Murphy
# 1    This is the first of a few episodes with five ...      Aarón Sánchez
# 2                                                  NaN      Aarón Sánchez
# 3    In the appetizer round, Chef Chuboda refused t...       Scott Conant
# 4                                                  NaN  Geoffrey Zakarian
# ..                                                 ...                ...
# 564  Chef Jose cut himself in the first round and c...       Chris Santos
# 565  Chef Arden forgot an ingredient in the first r...     Amanda Freitag
# 566  The guest judge in this episode was Chef Ray G...       Scott Conant
# 567  In this unofficially vegetarian themed episode...     Maneet Chauhan
# 568                                                NaN       Chris Santos
#
#                  judge2              judge3  \
# 0    Alex Guarnaschelli       Aarón Sánchez
# 1    Alex Guarnaschelli         Marc Murphy
# 2    Alex Guarnaschelli         Marc Murphy
# 3        Amanda Freitag   Geoffrey Zakarian
# 4    Alex Guarnaschelli         Marc Murphy
# ..                  ...                 ...
# 564        Scott Conant        Erik Ramirez
# 565      Maneet Chauhan        Scott Conant
# 566   Geoffrey Zakarian          Ray Garcia
# 567         Marc Murphy         Esther Choi
# 568      Maneet Chauhan  Geoffrey Zacharian
#
#                                       contestant1_info  \
# 0      Private Chef and Nutrition Coach  New York  NY
# 1     Private Caterer and Culinary Instructor  West...
# 2     Executive Chef and Co-owner  La Palapa  New Y...
# 3         Executive Chef  Ayza Wine Bar  New York  NY
# 4                         Personal Chef  New York  NY
# ..                                                 ...
# 564                  Chef and Owner from New York  NY
# 565              Chef and Owner from Laguna Beach  CA
# 566               Executive Chef from Los Angeles  CA
# 567             Executive Sous Chef from New York  NY
# 568                  Executive Chef from Portland  OR
#
#                                       contestant2_info  \
# 0     Private Chef and Sous chef  Bar Blanc  New Yo...
# 1     Chef de cuisine  Liberty National Golf Course...
# 2     Chef de cuisine  SoHo Grand Hotel  New York  NY
# 3     Chef  Registered Dietician and Culinary Consu...
# 4                        Executive Chef  New York  NY
# ..                                                 ...
# 564                   Executive Chef from Raleigh  NC
# 565                  Executive Chef from New York  NY
# 566               Executive Sous Chef from Boston  MA
# 567        Private Chef and Caterer from Brooklyn  NY
# 568             Chef de Cuisine from Philadelphia  PA
#
#                                       contestant3_info  \
# 0         Pastry Chef  Olana Restaurant  New York  NY
# 1     Executive Chef and Owner  Ted and Honey  Broo...
# 2                          Private Chef  New York  NY
# 3     Executive Chef  Knickerbocker Bar & Grill  Ne...
# 4     Executive Chef / Wine Director  Bloomingdale ...
# ..                                                 ...
# 564                    Executive Chef from Harlem  NY
# 565               Private Chef from Bradley Beach  NJ
# 566                  Executive Chef from Portland  OR
# 567     Executive Chef and Owner from Los Angeles  CA
# 568                 Chef and Owner from San Diego  CA
#
#                                       contestant4_info  \
# 0     Catering Chef  Showstoppers Catering at Union...
# 1     Owner and Chef  Chef for Hire LLC  Newville  PA
# 2     Chef tournant  L’Atelier de Joël Robuchon  Ne...
# 3                  Chef and Owner  Taïm  New York  NY
# 4     Chef de cuisine  Gordon Ramsay at The London ...
# ..                                                 ...
# 564                Chef and Owner from Providence  RI
# 565                 Executive Chef from Charlotte  NC
# 566    Research & Development Chef from San Diego  CA
# 567                  Chef and Owner from Portland  OR
# 568                    Executive Chef from Bethel  CT
#
#                                               combined
# 0    Octopus, Duck, Animal Crackers This is the fir...
# 1    Tofu, Blueberries, Oysters This is the first o...
# 2    Avocado, Tahini, Bran Flakes nan Aarón Sánchez...
# 3    Banana, Collard Greens, Grits In the appetizer...
# 4    Yucca, Watermelon, Tortillas nan Geoffrey Zaka...
# ..                                                 ...
# 564  Terrine Cuisine Chef Jose cut himself in the f...
# 565  Time and Turmoil Chef Arden forgot an ingredie...
# 566  Jarring Jars The guest judge in this episode w...
# 567  Cauliflower Power In this unofficially vegetar...
# 568  Quail Without Fail nan Chris Santos Maneet Cha...
#
# [569 rows x 10 columns]

# %%
for i, col in enumerate(chopped.columns):
    chopped.iloc[:, i] = chopped.iloc[:, i].str.replace('"', '')

# %%
chopped.shape
# Out:
# (569, 20)

# %%
chopped.isnull().sum()
# Out:
# season                0
# season_episode        0
# series_episode        0
# episode_name          0
# episode_notes       113
# air_date              0
# judge1                1
# judge2                1
# judge3                1
# appetizer             0
# entree                0
# dessert               1
# contestant1           1
# contestant1_info     13
# contestant2           0
# contestant2_info     14
# contestant3           0
# contestant3_info     13
# contestant4           0
# contestant4_info     14
# dtype: int64

# %%
# Drop irrelevant rows
#chopped = chopped.drop(columns=['season','season_episode','series_episode','air_date','appetizer','entree','dessert','contestant1','contestant2','contestant3','contestant4'])
keep = ['episode_name','episode_notes','judge1','judge2','judge3','contestant1_info','contestant2_info','contestant3_info','contestant4_info']
chopped = chopped[keep]
chopped.head()
# Out:
#                        episode_name  \
# 0  "Octopus, Duck, Animal Crackers"
# 1      "Tofu, Blueberries, Oysters"
# 2    "Avocado, Tahini, Bran Flakes"
# 3   "Banana, Collard Greens, Grits"
# 4    "Yucca, Watermelon, Tortillas"
#
#                                        episode_notes             judge1  \
# 0  This is the first episode with only three offi...        Marc Murphy
# 1  This is the first of a few episodes with five ...      Aarón Sánchez
# 2                                                NaN      Aarón Sánchez
# 3  In the appetizer round, Chef Chuboda refused t...       Scott Conant
# 4                                                NaN  Geoffrey Zakarian
#
#                judge2             judge3  \
# 0  Alex Guarnaschelli      Aarón Sánchez
# 1  Alex Guarnaschelli        Marc Murphy
# 2  Alex Guarnaschelli        Marc Murphy
# 3      Amanda Freitag  Geoffrey Zakarian
# 4  Alex Guarnaschelli        Marc Murphy
#
#                                     contestant1_info  \
# 0    Private Chef and Nutrition Coach  New York  NY
# 1   Private Caterer and Culinary Instructor  West...
# 2   Executive Chef and Co-owner  La Palapa  New Y...
# 3       Executive Chef  Ayza Wine Bar  New York  NY
# 4                       Personal Chef  New York  NY
#
#                                     contestant2_info  \
# 0   Private Chef and Sous chef  Bar Blanc  New Yo...
# 1   Chef de cuisine  Liberty National Golf Course...
# 2   Chef de cuisine  SoHo Grand Hotel  New York  NY
# 3   Chef  Registered Dietician and Culinary Consu...
# 4                      Executive Chef  New York  NY
#
#                                     contestant3_info  \
# 0       Pastry Chef  Olana Restaurant  New York  NY
# 1   Executive Chef and Owner  Ted and Honey  Broo...
# 2                        Private Chef  New York  NY
# 3   Executive Chef  Knickerbocker Bar & Grill  Ne...
# 4   Executive Chef / Wine Director  Bloomingdale ...
#
#                                     contestant4_info
# 0   Catering Chef  Showstoppers Catering at Union...
# 1   Owner and Chef  Chef for Hire LLC  Newville  PA
# 2   Chef tournant  L’Atelier de Joël Robuchon  Ne...
# 3                Chef and Owner  Taïm  New York  NY
# 4   Chef de cuisine  Gordon Ramsay at The London ...

# %%
# create new column to include all information in one string
chopped['combined'] = chopped[keep].apply(lambda row: ' '.join(row.values.astype(str)), axis=1)

# %%
# calculate TFIDFvectorizor scores

tfidf = TfidfVectorizer(ngram_range=(1,3),stop_words='english').fit_transform(chopped['combined'])
tfidf
# Out:
# <569x32654 sparse matrix of type '<class 'numpy.float64'>'
# 	with 68042 stored elements in Compressed Sparse Row format>

# %%
# calculate similarity scores between all episodes
cosine_sim = cosine_similarity(tfidf)

# %%
# create function to print similar episodes and similarity scores
def get_recs(episode_name):
    enumerated = enumerate(cosine_sim[chopped[chopped['episode_name'] == episode_name].index[0]])
    listed = list(enumerated)
    sorteds = sorted(listed,key = lambda x:x[1], reverse=True)[:10]
    return sorteds

# create function to print names of similar episodes
def get_names(episode_name):
    sorteds = get_recs(episode_name)
    j = 0
    for i in sorteds[1:]:
        episode = chopped[chopped.index == i[0]]['episode_name'].values[0]
        print('Episode ', i[0]+1, ': ', episode)
        j+=1

# %%
# test function
episode = "Octopus, Duck, Animal Crackers"
get_recs(episode)
# Out:
# [(0, 1.0000000000000002),
#  (33, 0.1896255745815175),
#  (36, 0.18179629236395303),
#  (22, 0.15970584747531077),
#  (83, 0.12501158460818734),
#  (325, 0.12385089718012214),
#  (41, 0.11873203712757194),
#  (35, 0.11824555044912897),
#  (2, 0.11393884962761658),
#  (53, 0.11371975688485567)]

# %%
# test get_names
get_names(episode)
# Out:
# Episode  34 :  Sweet Redemption
# Episode  37 :  Raw Enthusiasm
# Episode  23 :  Chopped Champions Event, Round One: The Ultimate Face-off
# Episode  84 :  Bite Your Pickled Beef Tongue
# Episode  326 :  Healthy Rivalry
# Episode  42 :  Jitters & Giant Eggs
# Episode  36 :  In A Pinch
# Episode  3 :  Avocado, Tahini, Bran Flakes
# Episode  54 :  Wok This Way

# %%
get_names('Chopped All-Stars: Judges')
# Out:
# Episode  289 :  Judges' Face-Off
# Episode  120 :  All-Stars: Judge Remix
# Episode  74 :  All-Stars Tournament: Round Four – Chopped Judges
# Episode  170 :  Chopped All-Stars: Mega Chefs
# Episode  173 :  Chopped All-Stars: Finale!
# Episode  229 :  Chopped Tournament of Stars: Sports Stars!
# Episode  117 :  All-Stars: Iron Chefs Do Battle
# Episode  505 :  Thankful Siblings
# Episode  172 :  Chopped All-Stars: Celebrities
